# %% [markdown]
# Lindsay Reisman & Jessie Bologna
#
#
# ML Final Report - Spring 2021

# %% [markdown]
# # Introduction

# %% [markdown]
#     "Microarray Data of cell-free RNA across pregnancy time course" was downloaded from NCBI GEO database. The dataset focuses on cell-free RNA expression of 12 patients (including a non-pregnant control) over 3 trimesters and post-partum. 33,297 transcripts are measured in the dataset. By analyzing the expression and presence of cf-RNA in the blood, an overview of tissue development and overall health of a fetus can be determined (Koh et al., 2014). This study aimed to provide a non-invasive technique for examining fetal tissue development.
#
#     Our goal with this dataset is to determine what trimester a patient is in given the expression levels. From this analysis, we are hoping to find which transcript has the highest differential expression during the final stages of pregnancy. Using various Machine Learning models to classify the data to learn and understand how these transcripts are expressed and what up-regulate genes they code for during pregnancy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Methods

# %% [markdown]
# ##### Import data/Preprocessing

# %% [markdown]
#     The first step was to import the downloaded dataset into a pandas dataframe. After loading and viewing the data, we concluded that it required some preoprocessing. Any missing data was removed and the data was transposed in preparation for running our models. Using Log2 fold change to normalize the data and identify any outliers. Log2 fold change was suggested by a classmate during our presentation. Log2 fold is a great tool to help differentiate between original and fold change of a sample using a log2 base for all samples to hover around 0 and 1. As seen below, the normalized values were plotted to visualize the difference between each sample.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     Next we decided to take the highest differential expression between the 3rd trimester and post partum. In order to make an analysis on all 11 pregnant patients, we removed the non-pregnant control for this process. From the >33,000 transcripts, we focusesd on the top 15 highest differential expression transcripts and the lowest 15 differential expression. In doing this, we can concentrate on what genes are overly expressed during the later end of pregnancy. We ran a box plot of all transcripts for all patients for highest and lowest expression.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Method1

# %% [markdown]
# ### PCA

# %% [markdown]
# We thought running a PCA model would be the best way to display the weights between the top features as well as show an clustering between classes. As a result were were able to see there was a clear separation between third trimester and post-partum. As well as finding the feature with the heaviest weight.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Method2

# %% [markdown]
# ### SVM Models

# %% [markdown]
# We fit our X and y training sets through our model. We used the .predict() function to determine the accuracy. After running the model we saw that the model had an accuracy of 80%. We decided to run again with hypertuning the paramters for a better outcome.

# %% [raw]
# [0.66666667 0.66666667 1.         0.66666667 1.        ]
# 0.80 accuracy with a standard deviation of 0.16
# Predicted  2  3  4
# Actual
# 1          6  0  0
# 2          1  0  0
# 3          1  2  0
# 4          0  0  4
# Accuracy = 0.5
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         6
#            2       0.12      1.00      0.22         1
#            3       1.00      0.67      0.80         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.50        14
#    macro avg       0.53      0.67      0.51        14
# weighted avg       0.51      0.50      0.47        14

# %% [markdown]
# ##### Updated SVM Model

# %% [markdown]
# By updating the parmeters to a linear kernel and a C regularization of 0.05 our accuracy was updated to an accuracy of 100%.

# %% [raw]
# Predicted  1  2  3  4
# Actual
# 1          6  0  0  0
# 2          0  1  0  0
# 3          0  0  3  0
# 4          0  0  0  4
# Accuracy = 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         4
#
#     accuracy                           1.00        14
#    macro avg       1.00      1.00      1.00        14
# weighted avg       1.00      1.00      1.00        14

# %% [markdown]
# # Discussion

# %% [markdown]
# As we saw from our model, we were able to conclude that runnning differential expression between time series of the top most highest expression transcripts was more advantangeous for creating concrete results we can further examine.
